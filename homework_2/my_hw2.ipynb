# %% [markdown]
# # Homework 2 - TF-IDF Classifier
#
# Цель обучить классификатор который будет находить "токсичные" комментарии и опубликовать решения на Kaggle [Toxic Comment Classification Challenge](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge)
#
#
# Данные можно скачать тут - https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data

# %% [markdown]
# # Input

# %%
import numpy as np
import pandas as pd
import eli5

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# %%
class_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
train = pd.read_csv('train.csv').fillna(' ')
test = pd.read_csv('test.csv').fillna(' ')

train_text = train['comment_text']
test_text = test['comment_text']
all_text = pd.concat([train_text, test_text])

# %% [markdown]
# # Most popular word

# %%
word_vect = TfidfVectorizer( binary= True )
words = word_vect.fit_transform(all_text)
word_vect.get_feature_names()[words.sum(axis =0 ).argmax()]
# Out:
# 'the'

# %% [markdown]
# # TfidfVectorizer and LogisticRegression

# %%
word_vectorizer = TfidfVectorizer( binary= True , lowercase=True , min_df = 3 , ngram_range = (1 , 1))
word_vectorizer.fit(all_text)
train_word_features = word_vectorizer.transform(train_text)
test_word_features = word_vectorizer.transform(test_text)
word_vectorizer
# Out:
# TfidfVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=3,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
classifier = LogisticRegression(C =2.3 , solver ='sag' , n_jobs =-1  ) 
classifier
# Out:
# LogisticRegression(C=2.3, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
scores= []
for class_name in class_names:
    train_target = train[class_name]
    cv_score = np.mean(cross_val_score(classifier, train_word_features, train_target, scoring='roc_auc'))
    print('CV score for class {} is {}'.format(class_name, cv_score))
    scores.append(cv_score)

print('Total score is {}'.format(np.mean(scores)))
# Out:
# CV score for class toxic is 0.972707503712865
# CV score for class severe_toxic is 0.9849429551050419
# CV score for class obscene is 0.9858540528402363
# CV score for class threat is 0.9878726550640627
# CV score for class insult is 0.9782607820060188
# CV score for class identity_hate is 0.975904393839754
# Total score is 0.9809237237613297

# %% [markdown]
# # My best solution

# %% [markdown]
# ### Parameter selection

# %% [markdown]
# в ходе эксперимента было выяснено , что в моей модели vectorizer.fit(train_text) дает больше скора на кагл чем vectorizer.fit(all_text)
#  vectorizer.fit(train_text) --> на кагл 0.9765 /
#  vectorizer.fit(all_text) --> на кагл 0.9761

# %%
vectorizer = {}
train_features = {}
test_features = {}
classifier = {}
score = {}

# %% [markdown]
# #### toxic

# %%
targ = 'toxic'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 3,  lowercase=True , ngram_range= (1,1) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'toxic'
classifier[targ] = LogisticRegression(C =3.5 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'toxic'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc'))
print(str(score[targ]) + ' current')
# Out:
# 0.9728747742665352 current

# %% [markdown]
# #### severe_toxic

# %%
targ = 'severe_toxic'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 3,  lowercase=True , ngram_range= (1,2) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'severe_toxic'
classifier[targ] = LogisticRegression(C =2 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'severe_toxic'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc'))
print(str(score[targ]) + ' current')
# Out:
# 0.9857956177490866 current

# %% [markdown]
# #### obscene

# %%
targ = 'obscene'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 3,  lowercase=True , ngram_range= (1,1) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'obscene'
classifier[targ] = LogisticRegression(C =2.5 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'obscene'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc'))
print(str(score[targ]) + ' current')
# Out:
# 0.9858725782679101 current

# %% [markdown]
# #### threat

# %%
targ = 'threat'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 4,  lowercase=True , ngram_range= (1,2) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'threat'
classifier[targ] = LogisticRegression(C =7 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'threat'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc')) 
print(str(score[targ]) + ' current')
# Out:
# 0.9891099555926052 current

# %% [markdown]
# #### insult

# %%
targ = 'insult'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 5,  lowercase=True , ngram_range= (1,1) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'insult'
classifier[targ] = LogisticRegression(C =2 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'insult'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc'))
print(str(score[targ]) + ' current')
# Out:
# 0.9782512376825944 current

# %% [markdown]
# #### identity_hate

# %%
targ = 'identity_hate'
vectorizer[targ] = TfidfVectorizer( binary= True , min_df = 3,  lowercase=True , ngram_range= (1,1) )
vectorizer[targ].fit(all_text)
train_features[targ] = vectorizer[targ].transform(train_text)
#test_features[targ] = vectorizer[targ].transform(test_text)

# %%
targ = 'identity_hate'
classifier[targ] = LogisticRegression(C =2 , solver ='sag' , n_jobs =-1  )

# %%
targ = 'identity_hate'
score[targ] = np.mean(cross_val_score(classifier[targ], train_features[targ], train[targ], scoring='roc_auc'))
print(str(score[targ]) + ' current')
# Out:
# 0.9759325888553004 current

# %% [markdown]
# ### Total score

# %% [markdown]
# Max Kaggle score : 0.9765

# %%
np.mean([score[el] for el in class_names ])
# Out:
# 0.9813061254023387

# %% [markdown]
# #### submission

# %%
submission = pd.DataFrame.from_dict({'id': test['id']})
for class_name in class_names:
    test_features[class_name] = vectorizer[class_name].transform(test_text)
    classifier[class_name].fit( train_features[class_name] , train[class_name])
    submission[class_name] = classifier[class_name].predict_proba(test_features[class_name])[:, 1] 
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # Model Analysis

# %%
target = 'toxic'
lr = classifier[target].fit(train_features[target] , train[target] )
eli5.explain_weights(lr , top = (100 , 100), feature_names = vectorizer[target].get_feature_names()  )
# Out:
# Explanation(estimator="LogisticRegression(C=3.5, class_weight=None, dual=False, fit_intercept=True,\n          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,\n          penalty='l2', random_state=None, solver='sag', tol=0.0001,\n          verbose=0, warm_start=False)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=1, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='fuck', weight=25.727691465491834, std=None, value=None), FeatureWeight(feature='fucking', weight=21.80554272602474, std=None, value=None), FeatureWeight(feature='shit', weight=17.72183152103856, std=None, value=None), FeatureWeight(feature='stupid', weight=17.574403713479168, std=None, value=None), FeatureWeight(feature='idiot', weight=17.189435437083628, std=None, value=None), FeatureWeight(feature='bullshit', weight=14.61741872584398, std=None, value=None), FeatureWeight(feature='ass', weight=13.77327156436824, std=None, value=None), FeatureWeight(feature='suck', weight=13.405486293548265, std=None, value=None), FeatureWeight(feature='asshole', weight=12.903356741703531, std=None, value=None), FeatureWeight(feature='bitch', weight=12.1166412653424, std=None, value=None), FeatureWeight(feature='dick', weight=12.075871300615297, std=None, value=None), FeatureWeight(feature='sucks', weight=11.99611966258795, std=None, value=None), FeatureWeight(feature='crap', weight=11.633752099981306, std=None, value=None), FeatureWeight(feature='faggot', weight=11.066275938292398, std=None, value=None), FeatureWeight(feature='fucked', weight=10.872561501534511, std=None, value=None), FeatureWeight(feature='penis', weight=10.442423446744579, std=None, value=None), FeatureWeight(feature='idiots', weight=10.435303181942288, std=None, value=None), FeatureWeight(feature='bastard', weight=10.274586694715643, std=None, value=None), FeatureWeight(feature='moron', weight=9.809752566351849, std=None, value=None), FeatureWeight(feature='pathetic', weight=9.280799519576027, std=None, value=None), FeatureWeight(feature='cunt', weight=9.072023721072009, std=None, value=None), FeatureWeight(feature='nigger', weight=8.982990195772812, std=None, value=None), FeatureWeight(feature='hell', weight=8.955881495501304, std=None, value=None), FeatureWeight(feature='gay', weight=8.839601832940257, std=None, value=None), FeatureWeight(feature='shut', weight=8.672867971567062, std=None, value=None), FeatureWeight(feature='jerk', weight=8.627648353060705, std=None, value=None), FeatureWeight(feature='dumbass', weight=8.560698726742066, std=None, value=None), FeatureWeight(feature='cock', weight=8.509019679268494, std=None, value=None), FeatureWeight(feature='fucker', weight=8.502814875791646, std=None, value=None), FeatureWeight(feature='idiotic', weight=8.468160316134638, std=None, value=None), FeatureWeight(feature='dumb', weight=8.384882252252838, std=None, value=None), FeatureWeight(feature='assholes', weight=8.364272061662021, std=None, value=None), FeatureWeight(feature='motherfucker', weight=8.286528297843528, std=None, value=None), FeatureWeight(feature='stupidity', weight=7.899909626128007, std=None, value=None), FeatureWeight(feature='pussy', weight=7.851132089611848, std=None, value=None), FeatureWeight(feature='morons', weight=7.521779940773575, std=None, value=None), FeatureWeight(feature='ck', weight=7.462336938490894, std=None, value=None), FeatureWeight(feature='loser', weight=7.4242604658353875, std=None, value=None), Fea ...

# %%
textTMP = test_text.sample().iloc[0]
eli5.explain_prediction(lr,textTMP, vec=vectorizer[target], feature_names=vectorizer[target].get_feature_names())
# Out:
# Explanation(estimator="LogisticRegression(C=3.5, class_weight=None, dual=False, fit_intercept=True,\n          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,\n          penalty='l2', random_state=None, solver='sag', tol=0.0001,\n          verbose=0, warm_start=False)", description=None, error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=0, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=3.135639534722945, std=None, value=1.0), FeatureWeight(feature='thank', weight=0.3639514931047066, std=None, value=0.05721335261480433), FeatureWeight(feature='agree', weight=0.19853758438112915, std=None, value=0.06618491513622543), FeatureWeight(feature='fought', weight=0.1897937273524641, std=None, value=0.11033983857108212), FeatureWeight(feature='inform', weight=0.1541231188386241, std=None, value=0.10183003052109929), FeatureWeight(feature='further', weight=0.14222975485279646, std=None, value=0.07111603180905475), FeatureWeight(feature='refer', weight=0.11847098884854475, std=None, value=0.0843865275947778), FeatureWeight(feature='there', weight=0.10509193837214614, std=None, value=0.04111238478934801), FeatureWeight(feature='apart', weight=0.10018201671098453, std=None, value=0.09915632928120274), FeatureWeight(feature='ethnic', weight=0.09717684011432595, std=None, value=0.09695285398847192), FeatureWeight(feature='saw', weight=0.09637631681497648, std=None, value=0.08012494055829238), FeatureWeight(feature='currently', weight=0.09440537750542663, std=None, value=0.07642461160947284), FeatureWeight(feature='as', weight=0.0869617244267435, std=None, value=0.034305797309052095), FeatureWeight(feature='would', weight=0.080586262994386, std=None, value=0.04362212840485996), FeatureWeight(feature='original', weight=0.07446188543456153, std=None, value=0.06921370741396339), FeatureWeight(feature='didn', weight=0.0688303719977179, std=None, value=0.06494616992712164), FeatureWeight(feature='rather', weight=0.06752785247217653, std=None, value=0.06644975709238514), FeatureWeight(feature='friends', weight=0.06616767677790789, std=None, value=0.08836122122435078), FeatureWeight(feature='think', weight=0.06303610420220546, std=None, value=0.04727366282930318), FeatureWeight(feature='but', weight=0.062311847966880836, std=None, value=0.036346806967565363), FeatureWeight(feature='if', weight=0.06077755905712032, std=None, value=0.035440894102174915), FeatureWeight(feature='for', weight=0.058193372692200415, std=None, value=0.030241964346631556), FeatureWeight(feature='we', weight=0.05795815099422167, std=None, value=0.04690386126294133), FeatureWeight(feature='called', weight=0.05742933030244966, std=None, value=0.06945769352645743), FeatureWeight(feature='the', weight=0.05666401851553961, std=None, value=0.02050852562160639), FeatureWeight(feature='information', weight=0.056055992343398885, std=None, value=0.05684992467364089), FeatureWeight(feature='to', weight=0.05176076521924237, std=None, value=0.022454278385122126), FeatureWeight(feature='two', weight=0.05111451059780457, std=None, value=0.06014603078367113), FeatureWeight(feature='came', weight=0.05032737935800126, std=None, value=0.07787133380480168), FeatureWeight(feature='has', weight=0.0502699991800639, std=None, value=0.04345715152408131), FeatureWeight(feature='impossible', weight=0.05026610600228146, std=None, value=0.09746854844902225), FeatureWeight(feature='dialects', weight=0.04850424932382551, std=None, value=0.1238012798014661), FeatureWeight(feature='pretty', weight=0.04774148787376563, std=None, value=0.07571504668083655), FeatureWeight(feature='first', weight=0.04520808566665976, std=None, value=0.05630449227341865), FeatureWeight(feature='when', weight=0.04376298907349911, std=None, value=0.05045413234693347), FeatureWeight(feature='lot', weight=0.04367376063284257, std=None, value=0.06976472227300744), FeatureWeight(feature='from', weight=0.04255191499725018, std=None, value=0.03972193973933 ...

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Greedy parameters selection

# %% [markdown]
# TfidfVectorizer( min_df = 1....5  , ngram_range = (1 , 1...2 ))
#
# LogisticRegression(C = 1....10 )

# %%
# %%time
vectorizer_best_1_1 = []
for i in range(1,11):
    print('runing {} of 20'.format(i))
    tmp =TfidfVectorizer( binary= True , min_df = i ,  lowercase=True)
    tmp.fit(all_text)
    vectorizer_best_1_1.append({'train':tmp.transform(train_text) , 'test' :tmp.transform(test_text)})
vectorizer_best_1_2 = []
for i in range(1,11):
    print('runing {} of 20'.format(i+10))
    tmp =TfidfVectorizer( binary= True , min_df = i ,  lowercase=True , ngram_range = (1 , 2))
    tmp.fit(all_text)
    vectorizer_best_1_2.append({'train':tmp.transform(train_text) , 'test' :tmp.transform(test_text)})
# Out:
# runing 1 of 20
# runing 2 of 20
# runing 3 of 20
# runing 4 of 20
# runing 5 of 20
# runing 6 of 20
# runing 7 of 20
# runing 8 of 20
# runing 9 of 20
# runing 10 of 20
# runing 11 of 20
# runing 12 of 20
# runing 13 of 20
# runing 14 of 20
# runing 15 of 20
# runing 16 of 20
# runing 17 of 20
# runing 18 of 20
# runing 19 of 20
# runing 20 of 20
# Wall time: 24min 58s

# %%
# %%time
best = {}
for targ in class_names:
    print(targ)
    maxScore = 0
    for i in range(5):
        train_featuresTMP = vectorizer_best_1_1[i]['train']
        for tmpC in range(1,11):
            classifierTMP = LogisticRegression(C =tmpC , solver ='sag' , n_jobs =-1  )
            score = np.mean(cross_val_score(classifierTMP, train_featuresTMP, train[targ], scoring='roc_auc'))
            str_text = ' 1_1 | min_df : {} | C : {} | score {}'.format(i+1 , tmpC , score)
            print(str_text)
            if score > maxScore:
                maxScore = score
                best[targ] = {'text': str_text , 'vectorizer':vectorizer_best_1_1[i] ,'classifier':classifierTMP , 'score': score }
    maxScore = 0
    for i in range(5):
        train_featuresTMP = vectorizer_best_1_2[i]['train']
        for tmpC in range(1,11):
            classifierTMP = LogisticRegression(C =tmpC , solver ='sag' , n_jobs =-1  )
            score = np.mean(cross_val_score(classifierTMP, train_featuresTMP, train[targ], scoring='roc_auc'))
            str_text = ' 1_2 | min_df : {} | C : {} | score {}'.format(i+1 , tmpC , score)
            print(str_text)
            if score > maxScore:
                maxScore = score
                best[targ+'2'] = {'text': str_text , 'vectorizer':vectorizer_best_1_2[i] ,'classifier':classifierTMP , 'score': score}
    print(' best  '+ targ +' :' + best[targ]['text'])
    print(' best2 '+ targ +' :' + best[targ + '2']['text'])
# Out:
# toxic
#  1_1 | min_df : 1 | C : 1 | score 0.9699451966172824
#  1_1 | min_df : 1 | C : 2 | score 0.9719658306152249
#  1_1 | min_df : 1 | C : 3 | score 0.9724444777955149
#  1_1 | min_df : 1 | C : 4 | score 0.9724861533361214
#  1_1 | min_df : 1 | C : 5 | score 0.9723599743278483
#  1_1 | min_df : 1 | C : 6 | score 0.9721563647125038
#  1_1 | min_df : 1 | C : 7 | score 0.9719207098983005
#  1_1 | min_df : 1 | C : 8 | score 0.9716700684437893
#  1_1 | min_df : 1 | C : 9 | score 0.9714164984194097
#  1_1 | min_df : 1 | C : 10 | score 0.9711638107597086
#  1_1 | min_df : 2 | C : 1 | score 0.9705129125254569
#  1_1 | min_df : 2 | C : 2 | score 0.9724117162882567
#  1_1 | min_df : 2 | C : 3 | score 0.9728091995235796
#  1_1 | min_df : 2 | C : 4 | score 0.9727850172305511
#  1_1 | min_df : 2 | C : 5 | score 0.972600343822549
#  1_1 | min_df : 2 | C : 6 | score 0.9723475189510927
#  1_1 | min_df : 2 | C : 7 | score 0.9720635978374856
#  1_1 | min_df : 2 | C : 8 | score 0.9717673847862317
#  1_1 | min_df : 2 | C : 9 | score 0.9714712070254761
#  1_1 | min_df : 2 | C : 10 | score 0.9711799971418392
#  1_1 | min_df : 3 | C : 1 | score 0.9707052387873346
#  1_1 | min_df : 3 | C : 2 | score 0.9725300259270563
#  1_1 | min_df : 3 | C : 3 | score 0.9728753001623875
#  1_1 | min_df : 3 | C : 4 | score 0.972817702276703
#  1_1 | min_df : 3 | C : 5 | score 0.9726021516111841
#  1_1 | min_df : 3 | C : 6 | score 0.9723221570315728
#  1_1 | min_df : 3 | C : 7 | score 0.9720158559711511
#  1_1 | min_df : 3 | C : 8 | score 0.9716984716160916
#  1_1 | min_df : 3 | C : 9 | score 0.9713845079335135
#  1_1 | min_df : 3 | C : 10 | score 0.9710756983642471
#  1_1 | min_df : 4 | C : 1 | score 0.9707354388098719
#  1_1 | min_df : 4 | C : 2 | score 0.97251476596958
#  1_1 | min_df : 4 | C : 3 | score 0.9728339582116113
#  1_1 | min_df : 4 | C : 4 | score 0.9727505543280003
#  1_1 | min_df : 4 | C : 5 | score 0.972515782087362
#  1_1 | min_df : 4 | C : 6 | score 0.9722181403108016
#  1_1 | min_df : 4 | C : 7 | score 0.9718935313126349
#  1_1 | min_df : 4 | C : 8 | score 0.9715606818806335
#  1_1 | min_df : 4 | C : 9 | score 0.9712303150019524
#  1_1 | min_df : 4 | C : 10 | score 0.9709081109601154
#  1_1 | min_df : 5 | C : 1 | score 0.9707811330906403
#  1_1 | min_df : 5 | C : 2 | score 0.9725239828443417
#  1_1 | min_df : 5 | C : 3 | score 0.9728207488841004
#  1_1 | min_df : 5 | C : 4 | score 0.9727171825055105
#  1_1 | min_df : 5 | C : 5 | score 0.9724646066254864
#  1_2 | min_df : 3 | C : 3 | score 0.974308588345317
#  1_2 | min_df : 3 | C : 4 | score 0.9746923905722987
#  1_2 | min_df : 3 | C : 5 | score 0.9748239114393789
#  1_2 | min_df : 3 | C : 6 | score 0.9748431186551486
#  1_2 | min_df : 3 | C : 7 | score 0.9748109072981311
#  1_2 | min_df : 3 | C : 8 | score 0.9747472283873088
#  1_2 | min_df : 3 | C : 9 | score 0.9746710398310073
#  1_2 | min_df : 3 | C : 10 | score 0.9745877495411873
#  1_2 | min_df : 4 | C : 1 | score 0.9696236081137212
#  1_2 | min_df : 4 | C : 2 | score 0.9728964564010698
#  1_2 | min_df : 4 | C : 3 | score 0.9738652004583854
#  1_2 | min_df : 4 | C : 4 | score 0.9742006882278905
#  1_2 | min_df : 4 | C : 5 | score 0.9742882314060012
#  1_2 | min_df : 4 | C : 6 | score 0.9742679142176124
#  1_2 | min_df : 4 | C : 7 | score 0.9741977148297587
#  1_2 | min_df : 4 | C : 8 | score 0.974113555319672
#  1_2 | min_df : 4 | C : 9 | score 0.9740113487159738
#  1_2 | min_df : 4 | C : 10 | score 0.9739032830849057
#  1_2 | min_df : 5 | C : 1 | score 0.9700229290449283
#  1_2 | min_df : 5 | C : 2 | score 0.9731303717093797
#  1_2 | min_df : 5 | C : 3 | score 0.9740186295591032
#  1_2 | min_df : 5 | C : 4 | score 0.9742959426249262
#  1_2 | min_df : 5 | C : 5 | score 0.9743375515043167
#  1_2 | min_df : 5 | C : 6 | score 0.974281887158079
#  1_2 | min_df : 5 | C : 7 | score 0.9741813055607474
#  1_2 | min_df : 5 | C : 8 | score 0.974061527779969
#  1_2 | min_df : 5 | C : 9 | score 0.9739312491581574
#  1_2 | min_df : 5 | C : 10 | score 0.9737960219780307
#  best  identity_hate : 1_1 | min_df : 3 | C : 2 | score 0.9759326156727735
#  best2 identity_hate : 1_2 | min_df : 3 | C : 6 | score 0.9748431186551486
# Wall time: 6h 33min 17s

# %%
for coment_clas in class_names:
    print(coment_clas)
    print(' '+best[coment_clas]['text'])
    print(' '+best[coment_clas+'2']['text'])
print('final score :' + str(np.array([max( best[coment_clas]['score'], best[coment_clas+'2']['score'] ) for coment_clas in class_names]).mean()) )
# Out:
# toxic
#   1_1 | min_df : 3 | C : 3 | score 0.9728753001623875
#   1_2 | min_df : 3 | C : 10 | score 0.9726354216119689
# severe_toxic
#   1_1 | min_df : 3 | C : 1 | score 0.9853974976199646
#   1_2 | min_df : 3 | C : 2 | score 0.9857955224926819
# obscene
#   1_1 | min_df : 3 | C : 3 | score 0.9858564051634269
#   1_2 | min_df : 3 | C : 8 | score 0.9846872502487439
# threat
#   1_1 | min_df : 4 | C : 3 | score 0.9880372501604714
#   1_2 | min_df : 4 | C : 7 | score 0.9891102300948376
# insult
#   1_1 | min_df : 5 | C : 2 | score 0.978251315519493
#   1_2 | min_df : 5 | C : 4 | score 0.9778522195042552
# identity_hate
#   1_1 | min_df : 3 | C : 2 | score 0.9759326156727735
#   1_2 | min_df : 3 | C : 6 | score 0.9748431186551486
# final score :0.9813035648509333

# %% [markdown]
# # The End
